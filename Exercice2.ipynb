# %%
import turtle
from turtle import *

bgcolor ('black')
color ('green')
speed(100)
hideturtle()
b=0
while b <200:
  right(b)
  forward(b*3)
  b=b+1
turtle.mainloop()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[1], line 11
#       9 while b <200:
#      10   right(b)
# ---> 11   forward(b*3)
#      12   b=b+1
#      13 turtle.mainloop()
#
# File <string>:5, in forward(distance)
#
# Terminator:
